# %%
import napari
viewer = napari.Viewer()

# %%
import numpy as np
path = r"C:\rkka_Projects\cell_death_v2\Data\8. A549 cell death(20250404)\250404.153021.A549_death_01_TNFa.001.Group1.A2.T001P01.TCF"
file = TCFile(path, '2DMIP')
image = np.array([f for f in file])
viewer.add_image(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 path = r"C:\rkka_Projects\cell_death_v2\Data\8. A549 cell death(20250404)\250404.153021.A549_death_01_TNFa.001.Group1.A2.T001P01.TCF"
# ----> 3 file = TCFile(path, '2DMIP')
#       4 image = np.array([f for f in file])
#       5 viewer.add_image(image)
#
# NameError: name 'TCFile' is not defined

# %%
import matplotlib.pyplot as plt
import utils

slice = utils.image_normalization(image[20], min=1.33, max=1.40)
plt.imshow(slice)

# %%
viewer1 = napari.Viewer()

# %%
import numpy as np
import utils
from TCFile import TCFile
from PIL import Image

path = r"C:\rkka_Projects\cell_death_v2\Data\8. A549 cell death(20250404)\250404.153021.A549_death_01_TNFa.001.Group1.A2.T001P03.TCF"
file = TCFile(path, '2DMIP')
image = np.array([utils.resize_tomogram_mip(f, data_resolution=file.data_resolution, target_resolution=0.1632, mode='mip') for f in file])
# image = np.array([f for f in file])
viewer.add_image(image)
# Out:
# <Image layer 'image' at 0x1f61a267680>

# %%
from TCFile import TCFile
path = r"C:\rkka_Projects\cell_death_v2\Data\9. A549_FasL(20250410)\250409.170229.A549_FasL_01.025.Group3.B5.T025P01.TCF"
viewer.add_image(TCFile(path, '3D')[8])
# Out:
# <Image layer 'Image' at 0x2979cbb0e60>

# %%
TCFile(path, '3D').data_resolution
# Out:
# [np.float64(1.0080393552780151),
#  np.float64(0.22215908765792847),
#  np.float64(0.22215908765792847)]

# %%
file = TCFile(path, '3DFL', channel=i, only_one=True)
viewer.add_image(file[66])
# Out:
# <Image layer 'Image' at 0x29ecc6036b0>

# %%
from TCFile import TCFile
import numpy as np
import cv2
import utils

time = 72
# Load grayscale base image
path = r"C:\rkka_Projects\cell_death_v2\Data\9. A549_FasL(20250410)\250409.170229.A549_FasL_01.025.Group5.C4.T025P02.TCF"
base = TCFile(path, '2DMIP')
base_stack = np.array([utils.resize_tomogram_mip(b, base.data_resolution) for b in base])
# viewer.add_image(base_stack)

colors = ['Blue', 'Green', 'Red']

ch0_list = []
ch1_list = []
ch2_list = []
for time in range(len(base)):
    for i in range(1):
        file = TCFile(path, '3DFL', channel=i, only_one=True)
        temp = np.max(file[time], axis=0)
        temp = cv2.resize(temp, dsize=base_stack[0].shape)
        if i==0:
            ch0_list.append(temp)
        elif i==1:
            ch1_list.append(temp)
        elif i==2:
            ch2_list.append(temp)
            
ch0_stack = np.array(ch0_list)    
ch1_stack = np.array(ch1_list)
ch2_stack = np.array(ch2_list)
    
viewer.add_image(base_stack)
viewer.add_image(ch0_stack, opacity=0.3, colormap=colors[0])
# viewer.add_image(ch1_stack, opacity=0.3, colormap=colors[1])
# viewer.add_image(ch2_stack, opacity=0.3, colormap=colors[2])
# Out:
# <Image layer 'ch0_stack' at 0x2979d00c2c0>

# %%
apoptosis = [(539, 795), 
             (530, 774),
             (526, 770),
(520, 762),
(520, 762),
(520, 762),
(512, 761),
(512, 761),
(502, 754),
(496, 754),
(496, 754),
(440, 794),
(450, 781),
(450, 770),
(450, 770),
(450, 770),
(469, 765),
(470, 763),
(470, 772),
(470, 767),
(469, 771),
(466, 770),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761),
(495, 761)

]

# %%
necroptosis_0 = [(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573),
(551, 573)

]

# %%
necroptosis_1 = [(704, 392),
(719, 397),
(719, 397),
(719, 397),
(719, 397),
(719, 397),
(719, 397),
(719, 397),
(719, 397),
(719, 397),
(683, 377),
(728, 281),
(727, 307),
(737, 325),
(730, 333),
(724, 330),
(724, 330),
(724, 330),
(724, 330),
(724, 330),
(740, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381),
(734, 381)
]

# %%
necroptosis_2 = [(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145),
(180, 145)
]

# %%
necroptosis_3 = [
    (124, 499),
(92, 505),
(127, 497),
(94, 502),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492),
(86, 492)

]

# %%
live = [(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919),
(377, 919)
]

# %%
from PIL import Image
import torch
import utils
from torchvision import models
from TCFile import TCFile
import numpy as np
from tqdm import tqdm

model_path = r"C:\rkka_Projects\cell_death_v2\trained_models\test_5_classes_22.032991_0.9728_sota.pth"
path = r"C:\rkka_Projects\cell_death_v2\Data\9. A549_FasL(20250410)\250409.170229.A549_FasL_01.025.Group5.C4.T025P04.TCF"
# Load Model
model = models.resnet101(pretrained=True)
num_features = model.fc.in_features
model.fc = torch.nn.Sequential(
    torch.nn.Dropout(0.2),
    torch.nn.Linear(num_features, 5)
)
model.load_state_dict(torch.load(model_path))
model = model.cuda()

transform = models.ResNet101_Weights.IMAGENET1K_V2.transforms()
file = TCFile(path, '2DMIP')

# offset = [(0, 0), (-16,-16), (-16, 16), (16, -16), (16, 16)]
offset = [(0,0)]
# c3p4 : necrtoptosis_times = [12, 18, 19, 24, 30, 48]
# c3p4 : necroptosis_centers = [(727, 304), (724, 329), (724, 329), (724, 329), (723, 323), (717, 310)]

necroptosis_times = [0, 63, 69, 72, '3d']
necroptosis_centers = [(343, 629), (361, 522), (359, 521), (363, 526), (263, 384)]

apoptosis_times = [0, 12, 15, 18, 24, 30, 48]
apoptosis_centers = [(535, 795), (452, 785), (454, 767), (476, 763), (495, 769), (500, 763), (496, 758)]
# offset = [(0, 0)]
timelapse_probabilities = []
for time in tqdm(range(1)):
    # center = necroptosis_2[time]
    time = 0
    center = (594, 170)
    mid_probabilities = []
    
    f = utils.resize_tomogram_mip(file[time], data_resolution=file.data_resolution, target_resolution=0.1632, mode='mip')
    f = utils.image_normalization(f, min=1.33, max=1.40)
    
    for off in offset:
        a = f[center[0]-80+off[0]:center[0]+80+off[0], center[1]-80+off[1]:center[1]+80+off[1]]
        a = torch.from_numpy(a)

        outputs = []
        labels = []
        with torch.no_grad():
            model = model.eval()
            
            i = a.unsqueeze(0).repeat(3,1,1).float()
            i = transform(i)
            output = model(i.unsqueeze(0).cuda())
            outputs.append(output)
            labels.append(int(torch.max(output, 1)[1].cpu().numpy()[0]))
                
        # 확률 계산산
        import torch.nn.functional as F
        with torch.no_grad():
            # output = torch.from_numpy(wanted_probabilities[0])
            # Apply softmax to get probabilities
            probabilities = []
            for output in outputs:
                probs = F.softmax(output.cpu(), dim=1)  # shape: [1, 5]
                # If you want it as a simple list or tensor
                probs = probs.squeeze()  # shape: [5]
                probs = probs.numpy()
                probabilities.append(probs)
                
        mid_probabilities.append(probabilities[0])
    
    mid_probabilities = np.array(mid_probabilities)
    mid_probabilities = np.mean(mid_probabilities, axis=0)
    mid_probabilities = mid_probabilities / np.sum(mid_probabilities)
    timelapse_probabilities.append(mid_probabilities)

timelapse_probabilities
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 40.48it/s]
# [array([0.03452361, 0.02765473, 0.03700323, 0.0350857 , 0.8657327 ],
#        dtype=float32)]

# %%
centers = [
(96, 96),
(177, 202),
(288, 272),
(433, 324),
(96, 778),
(488, 731),
(594, 618),
(581, 100)

]

# %%
from PIL import Image
import torch
import utils
from torchvision import models
from TCFile import TCFile
import numpy as np
from tqdm import tqdm

model_path = r"C:\rkka_Projects\cell_death_v2\trained_models\test_5_classes_22.032991_0.9728_sota.pth"
path = r"C:\rkka_Projects\cell_death_v2\Data\9. A549_FasL(20250410)\250409.170229.A549_FasL_01.025.Group5.C4.T025P04.TCF"
# Load Model
model = models.resnet101(pretrained=True)
num_features = model.fc.in_features
model.fc = torch.nn.Sequential(
    torch.nn.Dropout(0.2),
    torch.nn.Linear(num_features, 5)
)
model.load_state_dict(torch.load(model_path))
model = model.cuda()

transform = models.ResNet101_Weights.IMAGENET1K_V2.transforms()
file = TCFile(path, '2DMIP')

offset = [(0, 0), (-16,-16), (-16, 16), (16, -16), (16, 16)]

# offset = [(0, 0)]
timelapse_probabilities = []
for time in tqdm(range(1)):
    # center = necroptosis_2[time]
    time = 0
    total = []
    for center in centers:
        mid_probabilities = []
        
        f = utils.resize_tomogram_mip(file[time], data_resolution=file.data_resolution, target_resolution=0.1632, mode='mip')
        f = utils.image_normalization(f, min=1.33, max=1.40)
        
        for off in offset:
            a = f[center[0]-80+off[0]:center[0]+80+off[0], center[1]-80+off[1]:center[1]+80+off[1]]
            a = torch.from_numpy(a)

            outputs = []
            labels = []
            with torch.no_grad():
                model = model.eval()
                
                i = a.unsqueeze(0).repeat(3,1,1).float()
                i = transform(i)
                output = model(i.unsqueeze(0).cuda())
                outputs.append(output)
                labels.append(int(torch.max(output, 1)[1].cpu().numpy()[0]))
                    
            # 확률 계산산
            import torch.nn.functional as F
            with torch.no_grad():
                # output = torch.from_numpy(wanted_probabilities[0])
                # Apply softmax to get probabilities
                probabilities = []
                for output in outputs:
                    probs = F.softmax(output.cpu(), dim=1)  # shape: [1, 5]
                    # If you want it as a simple list or tensor
                    probs = probs.squeeze()  # shape: [5]
                    probs = probs.numpy()
                    probabilities.append(probs)
                    
            mid_probabilities.append(probabilities[0])
        
        mid_probabilities = np.array(mid_probabilities)
        mid_probabilities = np.mean(mid_probabilities, axis=0)
        mid_probabilities = mid_probabilities / np.sum(mid_probabilities)
        mid_index = np.argmax(mid_probabilities)
        total.append(mid_index)
        

total
# Out:
# c:\miniconda3\envs\cell\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\miniconda3\envs\cell\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
# [np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(4),
#  np.int64(3),
#  np.int64(1),
#  np.int64(4),
#  np.int64(4)]

# %%
np.argmax(mid_probabilities)
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 5))

# Example dummy data
class_names = ['Apoptosis', 'Necroptosis', 'Necrosis', 'Control', 'Treated yet Alive']
colors = {1: '#FF9B9B', 2: '#FFD89C', 3: '#B99470', 4: '#3B6790', 5: "#98D8EF"}

for i, class_name in enumerate(class_names):
    color = colors[i + 1]
    plt.plot(np.array(timelapse_probabilities)[:, i], label=class_name, color=color, linewidth=3)

plt.title("Class Probabilities Over Time")
plt.xlabel("Time")
plt.ylabel("Probability")
plt.ylim(0, 1)
# plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
i = 3
offset = (0, 0)
cell = image[times[i]][centers[i][0]-80+offset[0]:centers[i][0]+80+offset[0], centers[i][1]-80+offset[1]:centers[i][1]+80+offset[1]]
plt.imshow(cell)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       2 i = 3
#       3 offset = (0, 0)
# ----> 4 cell = image[times[i]][centers[i][0]-80+offset[0]:centers[i][0]+80+offset[0], centers[i][1]-80+offset[1]:centers[i][1]+80+offset[1]]
#       5 plt.imshow(cell)
#
# NameError: name 'times' is not defined

# %%
TCFile(path, '3D').data_resolution[1:3]
# Out:
# [np.float64(0.22215908765792847), np.float64(0.22215908765792847)]

# %%
i = 3
file = TCFile(path, '3D')
image = file[72][:,:,383]
image = utils.resize_tomogram_mip(image, data_resolution=file.data_resolution[0:2])

offset = (16, 16)
cell = image
plt.imshow(cell)

# %%
import matplotlib.pyplot as plt
i = 0
offset = (16, 16)

file = TCFile(path, '2DMIP')
image = file[apoptosis_times[i]]
image = utils.resize_tomogram_mip(image, data_resolution=file.data_resolution)
cell = image[apoptosis_centers[i][0]-80-offset[0]:apoptosis_centers[i][0]+80+offset[0], 
                                 apoptosis_centers[i][1]-80-offset[1]:apoptosis_centers[i][1]+80+offset[1]]

plt.imshow(cell)

# %%
import matplotlib.pyplot as plt
i = 0
offset = (16, 16)
center = (885, 574)
file = TCFile(path, '2DMIP')
image = file[72]
image = utils.resize_tomogram_mip(image, data_resolution=file.data_resolution)
cell = image[center[0]-80-offset[0]:center[0]+80+offset[0], 
                                 center[1]-80-offset[1]:center[1]+80+offset[1]]

plt.imshow(cell)

# %%
from PIL import Image
cell = utils.image_normalization(cell, min=1.33, max=1.40)
im = Image.fromarray(cell)
im.save(f'figures/figure5/cell_a4p2_1_{20}_large.png')

# %%
import matplotlib.pyplot as plt

# Assuming you already have probs as a numpy array
class_names = ['Apoptosis', 'Necroptosis', 'Necrosis', 'Control', 'Treated yet Alive']  # change these to your actual class names

plt.bar(range(len(timelapse_probabilities[0])), timelapse_probabilities[0])
plt.xticks(range(len(timelapse_probabilities[0])), class_names, rotation=45)
plt.ylabel('Probability')
plt.title('Class Probabilities')
plt.tight_layout()
plt.ylim(0,1)
plt.savefig(f'figures/figure_supplementary/cell_c4p4_timelapse_1_{0}_prop.svg', format='svg')
plt.show()
